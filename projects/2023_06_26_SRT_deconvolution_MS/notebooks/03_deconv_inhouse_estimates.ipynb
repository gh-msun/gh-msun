# %% [markdown]
# # Compute Deconvolution of In-House EM-Seq Clinical Batches

# %% [markdown]
# ## Initialisation

# %%
import os
import numpy as np
import pandas as pd
import random
import glob
import datetime
import itertools
import altair as alt
import seaborn as sns
import matplotlib.pyplot as plt
#import plotly.express as px
import nbformat

pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 500)
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %% [markdown]
# ### Parameters and File Paths

# %%
FILTER_COV = 20
FILTER_COV_COEFF = 0.5
SCORE_VAR = 'frac_alpha_leq_25pct'
#--- Local paths
ROOT_DIR = '/analysis/'
PROJECT_SLUG = '2023_06_15_BCdeconvolution_AS'
PROJECT_DIR = ROOT_DIR + '/{}'.format(PROJECT_SLUG)

DATA_DIR = ROOT_DIR + '/{}'.format('2023_06_15_BCdeconvolution_AS/stage')

# Sample annotations
SAMPLE_PATH = DATA_DIR + ''
# Methylation data
SCORE_PATH = (
    PROJECT_DIR + '/output/meth_summaries/buffycoat_meth_summaries_cg_count_geq_3_deconvolution_v2.v23_conv.with_cpg_index.tsv.gz'
)
# Reference matrix
ATLAS_PATH = (
    PROJECT_DIR + '/output/ref/deconv_inhouse_v2.atlas.tsv.gz'
#    DATA_DIR + '/data/deconv/deconv_inhouse_v2.atlas.tsv.gz'
)
REGION_PATH = (
    PROJECT_DIR + '/output/ref/deconv_inhouse_v2.region_to_ref_celltype.tsv.gz'
)
# COVERAGE_PATH = (
#     PROJECT_DIR + '/data/region_coverage_estimates.deconvolution_v2.v23_conv.tsv'
# )
# Where to store graphics
RESULTS_PATH = PROJECT_DIR + '/output/deconv/deconv_inhouse_v2_blueprint'

# %% [markdown]
# ### Sample Metadata

# %%
# sample_df = pd.read_csv(SAMPLE_PATH, sep='\t')
# BATCH_MAP = {
#     '1': 'batch_12', '2': 'batch_12', 'normals_2': 'batch_12',
#     '3': 'batch_345', '4': 'batch_345', '5': 'batch_345',
# }
# sample_df['batch_group'] = sample_df['batch_id'].map(BATCH_MAP)
# #sample_df.iloc[0]

# %% [markdown]
# ### ATLAS

# %%
atlas = pd.read_csv(ATLAS_PATH, sep='\t')
atlas = atlas.set_index('region_id')
atlas.columns.name = 'ref_celltype'
atlas.shape
# Out:
# (280, 9)

# %%
ref_region_df = pd.read_csv(REGION_PATH, sep='\t')
ref_region_df.shape[0]
# Out:
# 280

# %% [markdown]
# Add coverage information.

# %%
# add_df = pd.read_csv(COVERAGE_PATH, sep='\t')
# ref_region_df = ref_region_df.merge(add_df[['region_id', 'coeff']], how='left')
# ref_region_df['coeff'].fillna(0, inplace=True)
# ref_region_df.shape[0]

# %%
#ridxs = (ref_region_df['coeff']>=FILTER_COV_COEFF)
#ref_region_df = ref_region_df[ridxs].copy()
#ref_region_df.shape[0], ref_region_df['region_id'].nunique()

# %%
atlas = atlas.loc[ref_region_df['region_id'], :].copy()
atlas.shape
# Out:
# (280, 9)

# %% [markdown]
# ### Methylation Scores

# %%
score_df = pd.read_csv(SCORE_PATH, sep='\t')
score_df['sample_id'].nunique()
#score_df['sample_id'] = score_df['tube_id'] was necessary for bip-ssm pipeline output
# Out:
# 10

# %%
score_df.head()
# Out:
#             sample_id                             region_id  number_molecules  \
# 0  SSM_12_kZJs0Vjyh4I  Breast_Basal_Ep-chr1:2463572-2463704               870
# 1  SSM_13_UaP270DP6ik  Breast_Basal_Ep-chr1:2463572-2463704              1535
# 2  SSM_14_KqhRdMUdMyg  Breast_Basal_Ep-chr1:2463572-2463704              1276
# 3  SSM_15_izoqP38MM5Z  Breast_Basal_Ep-chr1:2463572-2463704              1123
# 4  SSM_16_S00uDEZl3o8  Breast_Basal_Ep-chr1:2463572-2463704               919
#
#    meth_k1  unmeth_k1  total_k1  meth_k3  unmeth_k3  total_k3  meth_k4  \
# 0     2892        159      3051     1106          0      1306      348
# 1     5149        357      5506     1971          1      2425      674
# 2     4253        265      4518     1608          2      1950      498
# 3     3765        243      4008     1413          0      1748      458
# 4     3064        159      3223     1175          1      1382      359
#
#    unmeth_k4  total_k4  frac_alpha_leq_25pct  frac_alpha_geq_75pct     tube_id
# 0          0       438              0.000000              0.901149  P1816023-1
# 1          0       894              0.000651              0.891205  P1816038-1
# 2          0       680              0.001567              0.911442  P1816024-1
# 3          0       632              0.000000              0.902939  P1816102-1
# 4          0       465              0.001088              0.928183  P1816039-1

# %% [markdown]
# ## Compute Mixtures

# %%
from scipy.optimize import nnls

def compute_mixture(b, atlas):
    
    ridxs = ~b.isna()
    b_hat = b[ridxs]
    atlas_hat = atlas.loc[b_hat.index, :]
    fit = nnls(atlas_hat, b_hat)
    rv = pd.Series(fit[0], index=atlas_hat.columns)
    
    return(rv)

# %%
#DATA_SAMPLES = sample_df['sample_id'].tolist()
DATA_SAMPLES = score_df['sample_id'].unique()
len(DATA_SAMPLES)
# Out:
# 10

# %%
DATA_SAMPLES
# Out:
# array(['SSM_12_kZJs0Vjyh4I', 'SSM_13_UaP270DP6ik', 'SSM_14_KqhRdMUdMyg',
#        'SSM_15_izoqP38MM5Z', 'SSM_16_S00uDEZl3o8', 'SSM_17_YaE1jtBet3h',
#        'SSM_18_5lltWZyPyNZ', 'SSM_19_LPCY3EPZlY7', 'SSM_20_fxb2qd6Ed70',
#        'SSM_21_C8Rl1ZVct5d'], dtype=object)

# %%
ridxs = score_df['region_id'].isin(atlas.index)
ridxs &= score_df['sample_id'].isin(DATA_SAMPLES)
ridxs &= (score_df['number_molecules']>=FILTER_COV)
data = score_df[ridxs]\
    .pivot_table(index='region_id', columns='sample_id', values=SCORE_VAR) \
    .fillna(0)

# %%
fit_nnls = data.apply(lambda x: compute_mixture(x, atlas), axis=0)\
    .reset_index()\
    .melt(id_vars='ref_celltype', var_name='sample_id', value_name='coeff')
fit_nnls.iloc[0]
# Out:
# ref_celltype              immune_b
# sample_id       SSM_12_kZJs0Vjyh4I
# coeff                     0.147703
# Name: 0, dtype: object

# %%
compute_mixture(data.iloc[:,0], atlas)
# Out:
# ref_celltype
# immune_b                            0.147703
# immune_t                            0.480124
# immune_nk                           0.001350
# immune_dend_plus_macro_plus_mono    0.056035
# immune_eosi                         0.006534
# immune_neutro                       0.209922
# immune_eryth                        0.000000
# immune_mega                         0.000000
# eryth_prog                          0.000000
# dtype: float64

# %%
data.iloc[:,0].head()
# Out:
# region_id
# Eryth_prog-chr12:122875429-122875559    0.000000
# Eryth_prog-chr12:123471883-123472181    0.002107
# Eryth_prog-chr14:20871852-20872002      0.000000
# Eryth_prog-chr16:15790488-15790760      0.000000
# Eryth_prog-chr16:4494669-4494777        0.000000
# Name: SSM_12_kZJs0Vjyh4I, dtype: float64

# %%
data.head()
# Out:
# sample_id                             SSM_12_kZJs0Vjyh4I  SSM_13_UaP270DP6ik  \
# region_id
# Eryth_prog-chr12:122875429-122875559            0.000000            0.002793
# Eryth_prog-chr12:123471883-123472181            0.002107            0.001560
# Eryth_prog-chr14:20871852-20872002              0.000000            0.000000
# Eryth_prog-chr16:15790488-15790760              0.000000            0.000000
# Eryth_prog-chr16:4494669-4494777                0.000000            0.000758
#
# sample_id                             SSM_14_KqhRdMUdMyg  SSM_15_izoqP38MM5Z  \
# region_id
# Eryth_prog-chr12:122875429-122875559            0.000000            0.000000
# Eryth_prog-chr12:123471883-123472181            0.000938            0.000344
# Eryth_prog-chr14:20871852-20872002              0.000519            0.000000
# Eryth_prog-chr16:15790488-15790760              0.000000            0.000000
# Eryth_prog-chr16:4494669-4494777                0.000000            0.001837
#
# sample_id                             SSM_16_S00uDEZl3o8  SSM_17_YaE1jtBet3h  \
# region_id
# Eryth_prog-chr12:122875429-122875559            0.000000            0.004762
# Eryth_prog-chr12:123471883-123472181            0.001983            0.000522
# Eryth_prog-chr14:20871852-20872002              0.000710            0.001669
# Eryth_prog-chr16:15790488-15790760              0.000000            0.000756
# Eryth_prog-chr16:4494669-4494777                0.000000            0.001199
#
# sample_id                             SSM_18_5lltWZyPyNZ  SSM_19_LPCY3EPZlY7  \
# region_id
# Eryth_prog-chr12:122875429-122875559            0.000000            0.000000
# Eryth_prog-chr12:123471883-123472181            0.001001            0.002048
# Eryth_prog-chr14:20871852-20872002              0.000000            0.000588
# Eryth_prog-chr16:15790488-15790760              0.000000            0.000000
# Eryth_prog-chr16:4494669-4494777                0.000000            0.001042
#
# sample_id                             SSM_20_fxb2qd6Ed70  SSM_21_C8Rl1ZVct5d
# region_id
# Eryth_prog-chr12:122875429-122875559            0.002976            0.003597
# Eryth_prog-chr12:123471883-123472181            0.001212            0.001544
# Eryth_prog-chr14:20871852-20872002              0.001091            0.000000
# Eryth_prog-chr16:15790488-15790760              0.000481            0.000000
# Eryth_prog-chr16:4494669-4494777                0.002435            0.002081

# %%
atlas.shape
# Out:
# (280, 9)

# %%
atlas.head()
# Out:
# ref_celltype                              immune_b  immune_t  immune_nk  \
# region_id
# Immune_Broad_B-chr1:1114772-1114971       0.954541  0.006215   0.000000
# Immune_Broad_B-chr10:45390756-45390847    0.905821  0.008588   0.045092
# Immune_Broad_B-chr10:126289835-126290065  0.947659  0.003568   0.069420
# Immune_Broad_B-chr10:126290368-126290506  0.928200  0.005704   0.000000
# Immune_Broad_B-chr11:75988912-75989088    0.973406  0.006640   0.006439
#
# ref_celltype                              immune_dend_plus_macro_plus_mono  \
# region_id
# Immune_Broad_B-chr1:1114772-1114971                               0.012992
# Immune_Broad_B-chr10:45390756-45390847                            0.007154
# Immune_Broad_B-chr10:126289835-126290065                          0.009761
# Immune_Broad_B-chr10:126290368-126290506                          0.013708
# Immune_Broad_B-chr11:75988912-75989088                            0.003429
#
# ref_celltype                              immune_eosi  immune_neutro  \
# region_id
# Immune_Broad_B-chr1:1114772-1114971          0.005208       0.002255
# Immune_Broad_B-chr10:45390756-45390847       0.000000       0.008713
# Immune_Broad_B-chr10:126289835-126290065     0.000000       0.003088
# Immune_Broad_B-chr10:126290368-126290506     0.048423       0.001361
# Immune_Broad_B-chr11:75988912-75989088       0.000000       0.003071
#
# ref_celltype                              immune_eryth  immune_mega  \
# region_id
# Immune_Broad_B-chr1:1114772-1114971           0.013889     0.012048
# Immune_Broad_B-chr10:45390756-45390847        0.064953     0.021491
# Immune_Broad_B-chr10:126289835-126290065      0.000000     0.005155
# Immune_Broad_B-chr10:126290368-126290506      0.009259     0.000000
# Immune_Broad_B-chr11:75988912-75989088        0.008475     0.007576
#
# ref_celltype                              eryth_prog
# region_id
# Immune_Broad_B-chr1:1114772-1114971         0.030417
# Immune_Broad_B-chr10:45390756-45390847      0.206392
# Immune_Broad_B-chr10:126289835-126290065    0.055057
# Immune_Broad_B-chr10:126290368-126290506    0.031746
# Immune_Broad_B-chr11:75988912-75989088      0.113996

# %% [markdown]
# ## Compute Naive Cell Proportions

# %%
ridxs = score_df['sample_id'].isin(DATA_SAMPLES)
ridxs &= (score_df['number_molecules']>=FILTER_COV)
fit_naive = score_df[ridxs]\
    .merge(ref_region_df[['region_id', 'ref_celltype']])\
    .groupby(['sample_id', 'ref_celltype'])\
    [SCORE_VAR].mean()\
    .reset_index()\
    .rename(columns={SCORE_VAR: 'coeff'})
fit_naive.iloc[0]
# Out:
# sample_id       SSM_12_kZJs0Vjyh4I
# ref_celltype            eryth_prog
# coeff                     0.000536
# Name: 0, dtype: object

# %% [markdown]
# ## Combine Different Estimates

# %%
fit_combined = fit_nnls\
    .merge(fit_naive, on=['sample_id', 'ref_celltype'], 
           suffixes=['_nnls', '_naive'], how='outer')
fit_combined.iloc[0]
# Out:
# ref_celltype              immune_b
# sample_id       SSM_12_kZJs0Vjyh4I
# coeff_nnls                0.147703
# coeff_naive                0.14007
# Name: 0, dtype: object

# %% [markdown]
# ## Write Out

# %%
# ofile = RESULTS_PATH + '.estimates.tsv.gz'
# rv = fit_combined.copy()
# rv.to_csv(ofile, sep='\t', header=True, index=False)

# %%
# fit_combined.groupby('sample_id')

# %%
fit_combined
# Out:
#                         ref_celltype   sample_id  coeff_nnls  coeff_naive
# 0                           immune_b  P1816006-1    0.067293     0.067307
# 1                           immune_t  P1816006-1    0.268491     0.235414
# 2                          immune_nk  P1816006-1    0.045725     0.053343
# 3   immune_dend_plus_macro_plus_mono  P1816006-1    0.102458     0.095121
# 4                        immune_eosi  P1816006-1    0.024208     0.031924
# 5                      immune_neutro  P1816006-1    0.486761     0.419077
# 6                       immune_eryth  P1816006-1    0.000000     0.002813
# 7                        immune_mega  P1816006-1    0.000000     0.005244
# 8                         eryth_prog  P1816006-1    0.000000     0.001993
# 9                           immune_b  P1816012-1    0.016973     0.020603
# 10                          immune_t  P1816012-1    0.130824     0.117969
# 11                         immune_nk  P1816012-1    0.011046     0.019415
# 12  immune_dend_plus_macro_plus_mono  P1816012-1    0.030962     0.048931
# 13                       immune_eosi  P1816012-1    0.000849     0.017289
# 14                     immune_neutro  P1816012-1    0.774596     0.655847
# 15                      immune_eryth  P1816012-1    0.000000     0.001607
# 16                       immune_mega  P1816012-1    0.000000     0.003006
# 17                        eryth_prog  P1816012-1    0.000000     0.000900
# 18                          immune_b  P1816023-1    0.147703     0.140070
# 19                          immune_t  P1816023-1    0.480124     0.406862
# 20                         immune_nk  P1816023-1    0.001350     0.020442
# 21  immune_dend_plus_macro_plus_mono  P1816023-1    0.056035     0.055615
# 22                       immune_eosi  P1816023-1    0.006534     0.012931
# 23                     immune_neutro  P1816023-1    0.209922     0.188081
# 24                      immune_eryth  P1816023-1    0.000000     0.002786
# 25                       immune_mega  P1816023-1    0.000000     0.003877
# 26                        eryth_prog  P1816023-1    0.000000     0.000536
# 27                          immune_b  P1816024-1    0.038483     0.040103
# 28                          immune_t  P1816024-1    0.279408     0.243153
# 29                         immune_nk  P1816024-1    0.018156     0.029131
# 30  immune_dend_plus_macro_plus_mono  P1816024-1    0.052908     0.059443
# 31                       immune_eosi  P1816024-1    0.002518     0.014117
# 32                     immune_neutro  P1816024-1    0.525138     0.448972
# 33                      immune_eryth  P1816024-1    0.000000     0.002223
# 34                       immune_mega  P1816024-1    0.000000     0.002935
# 35                        eryth_prog  P1816024-1    0.000000     0.001166
# 36                          immune_b  P1816037-1    0.046711     0.047929
# 37                          immune_t  P1816037-1    0.184885     0.164205
# 38                         immune_nk  P1816037-1    0.018688     0.027597
# 39  immune_dend_plus_macro_plus_mono  P1816037-1    0.056161     0.063979
# 40                       immune_eosi  P1816037-1    0.017605     0.029750
# 41                     immune_neutro  P1816037-1    0.637826     0.544853
# 42                      immune_eryth  P1816037-1    0.000000     0.003007
# 43                       immune_mega  P1816037-1    0.000000     0.008803
# 44                        eryth_prog  P1816037-1    0.000000     0.001073
# 45                          immune_b  P1816038-1    0.026774     0.029798
# 46                          immune_t  P1816038-1    0.205376     0.182900
# 47                         immune_nk  P1816038-1    0.041414     0.047488
# 48  immune_dend_plus_macro_plus_mono  P1816038-1    0.062276     0.066405
# 49                       immune_eosi  P1816038-1    0.015605     0.026246
# 50                     immune_neutro  P1816038-1    0.558557     0.478028
# 51                      immune_eryth  P1816038-1    0.000000     0.002016
# 52                       immune_mega  P1816038-1    0.000000     0.004178
# 53                        eryth_prog  P1816038-1    0.000000     0.001092
# 54                          immune_b  P1816039-1    0.064890     0.064704
# 55                          immune_t  P1816039-1    0.368461     0.314679
# 56                         immune_nk  P1816039-1    0.012585     0.026846
# 57  immune_dend_plus_macro_plus_mono  P1816039-1    0.073172     0.069432
# 58                       immune_eosi  P1816039-1    0.011431     0.020323
# 59                     immune_neutro  P1816039-1    0.394120     0.341162
# 60                      immune_eryth  P1816039-1    0.000000     0.002848
# 61                       immune_mega  P1816039-1    0.000000     0.008520
# 62                        eryth_prog  P1816039-1    0.000000     0.001480
# 63                          immune_b  P1816102-1    0.046626     0.047256
# 64                          immune_t  P1816102-1    0.136714     0.124235
# 65                         immune_nk  P1816102-1    0.006043     0.015210
# 66  immune_dend_plus_macro_plus_mono  P1816102-1    0.029876     0.046822
# 67                       immune_eosi  P1816102-1    0.037224     0.047363
# 68                     immune_neutro  P1816102-1    0.669827     0.567553
# 69                      immune_eryth  P1816102-1    0.000000     0.002007
# 70                       immune_mega  P1816102-1    0.000000     0.005203
# 71                        eryth_prog  P1816102-1    0.000000     0.000618
# 72                          immune_b  P1816106-1    0.003828     0.008426
# 73                          immune_t  P1816106-1    0.074746     0.073074
# 74                         immune_nk  P1816106-1    0.012305     0.018820
# 75  immune_dend_plus_macro_plus_mono  P1816106-1    0.005947     0.035466
# 76                       immune_eosi  P1816106-1    0.011215     0.028456
# 77                     immune_neutro  P1816106-1    0.883283     0.746830
# 78                      immune_eryth  P1816106-1    0.000000     0.002569
# 79                       immune_mega  P1816106-1    0.000000     0.003992
# 80                        eryth_prog  P1816106-1    0.000000     0.001134
# 81                          immune_b  P1816108-1    0.016351     0.020833
# 82                          immune_t  P1816108-1    0.217673     0.192154
# 83                         immune_nk  P1816108-1    0.045701     0.052875
# 84  immune_dend_plus_macro_plus_mono  P1816108-1    0.091650     0.087983
# 85                       immune_eosi  P1816108-1    0.019461     0.028828
# 86                     immune_neutro  P1816108-1    0.541565     0.463724
# 87                      immune_eryth  P1816108-1    0.000000     0.001991
# 88                       immune_mega  P1816108-1    0.000000     0.006114
# 89                        eryth_prog  P1816108-1    0.000000     0.000792
